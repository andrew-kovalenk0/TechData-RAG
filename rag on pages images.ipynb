# %%
import base64
import os

from pypdfium2 import PdfDocument
from natsort import natsorted
from langchain_core.messages import HumanMessage
from langchain_openai.chat_models import ChatOpenAI
from langchain_openai.embeddings import OpenAIEmbeddings
import uuid
from langchain.schema.output_parser import StrOutputParser
from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.schema.document import Document
from langchain.storage import InMemoryStore
from langchain.vectorstores import Chroma
import io
import re
from IPython.display import HTML, display
from langchain.schema.runnable import RunnableLambda, RunnablePassthrough
from PIL import Image

# %%
pdf_name = 'ref_data/TWINGO/MR413X4416A000.pdf'

# %%
images_path = "ref_data/parsed_images/TWINGO/"
pdf = PdfDocument(pdf_name)
for i in range(len(pdf)):
    page = pdf[i]
    image = page.render(scale=4).to_pil()
    image.save(f"ref_data/parsed_images/page_{i}.jpg")

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


def image_summarize(img_base64, prev_base64_image, prompt):
    model = ChatOpenAI(model="gpt-4o-mini")
    msg = model(
        [
            HumanMessage(
                content=[
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/jpeg;base64,{img_base64}"},
                    },
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/jpeg;base64,{prev_base64_image}"},
                    },
                ]
            )
        ]
    )
    return msg.content


prompt = """
You are an assistant tasked with describing images for the RAG system.
These summaries will be embedded and used to produce the raw image.
Provide a short description of the image that will be well optimized for search.
Some images are sequential and connected, for example, the APN1 diagram continues
on 4 pages with notes Continuation 1-4, indicate this in your description in the form:
Continuation of the scheme [Scheme name] from page [page number].
Start the description with the page number of the document.
Pay attention that pages numbers could be not in regular format, in that case use page number as it is in the document.
Use previous page image to improve current page description, for example you could add to the
description that at the current page #5 there is some schema, that starts on the page #4.
"""

prev_image_path = ''
images_base64_list = []
images_summaries = []
for img_file in natsorted(os.listdir(images_path)):
    if img_file.endswith(".jpg"):
        image_path = os.path.join(images_path, img_file)
        base64_image = encode_image(image_path)
        images_base64_list.append(base64_image)
        prev_base64_image = encode_image(prev_image_path) if prev_image_path != '' else encode_image(image_path)
        images_summaries.append(image_summarize(base64_image, prev_base64_image, prompt))
        prev_image_path = image_path
# Out:
# c:\Users\andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(

# %%
images_summaries
# Out:
# ['**Page 2:** This page includes the table of contents for the Twingo II manual, specifically section 16A, which covers the engine start and battery charging diagnostics. It lists various diagnostic topics such as element placement and function, along with their corresponding page numbers. Continuation of the scheme from page 1.',
#  '**Page 16A-2 Description**: This page features detailed diagrams related to the engine start and battery charging system of the Twingo II. It includes labeled illustrations of the starter (1) and generator (2) positioned on the engine, along with a close-up of the fuse box (3) located inside the vehicle. The diagrams provide a visual reference for identifying key components. This page is part of the continuation of the diagnostic series for the engine and its systems, following the overview found on page 16A-1.',
#  "**Page 16A-3**: This page provides detailed information on the components of the Twingo II's starting and charging system, focusing on the accumulator battery, generator, and starter. It explains the role of the accumulator battery in supplying energy to start the engine, ensuring optimal connections, and maintaining electrical systems. The generator's function is outlined, emphasizing its operation when the engine is running and its role in charging the battery. It also describes the starter's critical function in engine ignition and its power requirements. \n\n**Continuation of the scheme Twingo II from page 16A-2**: Page 16A-2 features diagrams labeling the starter and generator components, along with their respective positions in the engine. The visual aids enhance understanding of the system's layout and component functions.",
#  "**Page 16A-4**: This page features a block diagram illustrating the starting system and battery charging for the Twingo II. The diagram includes components such as the accumulator battery, starter, generator, and control unit, with labeled connections indicating their roles in the system. This page continues from page 16A-3, which provides detailed descriptions of each component's function, including the battery's role in supplying energy to the starter and the generator's operation.",
#  '**Page 16A-5:** This page outlines the objectives of charging the accumulator battery and includes diagnostic functions for engine start and battery charging. It details the purpose of the charging system, including energy supply for the vehicle and monitoring generator load. The text mentions the optimization of battery charging and checks for circuit integrity. This page follows the functional scheme presented on **page 16A-4**, which includes a block diagram of the engine starting and battery charging system.',
#  '**Page 16A-6:** This page presents a flowchart outlining troubleshooting steps for engine starting issues related to the starter motor and battery charging system for the Twingo II. It includes pathways for various scenarios such as the starter not working, unusual starter noise, and insufficient starter rotation frequency. References to more detailed diagrams are indicated, specifically pointing to the continuation of the troubleshooting scheme beginning on page 16A-1. \n\n**Page 16A-5:** This page provides an overview of the battery charging and engine starting diagnostics for the Twingo II. It describes the purpose of the battery charging system, which includes supplying electrical energy to the vehicle, monitoring generator load, and optimizing battery charging. It also outlines the intended use of the starting circuit when the ignition key is turned.',
#  '**Page 16A-7**: This page features a diagnostic flowchart for troubleshooting a non-functioning starter in a Twingo II vehicle. The flowchart outlines steps to check the battery, connections, and wiring integrity. It provides instructions for ensuring proper tightness of connections and verifying the condition of specific wires related to the starter and battery. This page continues from the previous page (16A-6), which introduces the issue of the starter not working and directs to this diagnostic process.',
#  '**Page 16A-8:** Continuation of the APN1 diagram from page 16A-7. This page outlines diagnostic steps for checking the starter and battery connections in a Twingo II vehicle. It includes flowchart instructions for measuring voltage between various components, assessing the integrity of the starter, and provides troubleshooting tips related to electrical connections. Key actions involve measuring voltage while engaging the starter and replacing faulty components as necessary.\n\n**Page 16A-7:** This page presents initial diagnostic instructions for a non-functioning starter in the Twingo II. It includes checks for battery condition, tightening of connections, and verifying wiring integrity. A flowchart guides users through steps to ensure proper connections and troubleshoot issues before attempting to start the engine. Instructions reference maintenance manual sections for detailed guidance on battery and starter inspections.',
#  '**Page 16A-9:** Continuation of the APN1 diagram from page 16A-8. This page outlines diagnostic steps for the starter motor and battery charging system in a Twingo II. It includes instructions for measuring voltage between various points in the starter circuit, emphasizing the importance of voltage readings during starter activation. Specific actions are recommended based on the measured voltage values, including replacing the starter or correcting wiring issues.\n\n**Page 16A-8:** Continuation of the APN1 diagram, providing initial diagnostic steps for the starter motor and battery charging system. It details the process for measuring voltage between the battery and starter connections while the starter is activated and includes guidance on troubleshooting potential faults based on voltage readings. Further instructions are given for checking component connections and ensuring proper functionality before proceeding with replacements.',
#  '**Page 10: Continuation of the scheme APN 1 from page 9.** This page provides diagnostic algorithms for checking the starting system of the Twingo II, specifically focusing on the presence of electrical issues, voltage measurements, and necessary repairs. It guides users through various checks, including verifying voltage at specific terminals and ensuring proper connections. Key components and troubleshooting steps are referenced, emphasizing the importance of inspecting wiring and testing for voltage inconsistencies.',
#  '**Page 4: Continuation of the scheme APN 1.** This page features a diagnostic flowchart for troubleshooting the engine start and battery charging system. It includes steps to check for voltage presence at specific components and provides instructions for testing and repairing electrical connections. Key components referenced are 232 and 163, with notes on necessary repairs and further guidance for resolving identified issues.\n\n**Page 3: Continuation of the scheme APN 1.** This page outlines the diagnostic process for identifying issues related to the starter relay and other electrical components. It includes checks for voltage presence and conditions for engine start, along with troubleshooting steps for various electrical faults. References to repair notes and component locations are provided to assist in diagnosing problems effectively.',
#  "**Page 16A-12**: This page features a diagnostic flowchart for troubleshooting a starter motor issue where the armature does not rotate when the starter is engaged. It includes steps such as removing the starter, checking the pinion gear for damage, and verifying the starter's condition. References to a repair manual for further instructions are provided throughout.\n\n**Continuation of the scheme APN1 from page 16A-11**: This page continues the diagnostic procedure from page 16A-11, which outlines checks for electrical components and circuit integrity related to the starter operation.",
#  "**Page 16A-13:** This page contains a diagnostic flowchart for addressing unusual starter noises when the engine is cranked. It guides users through steps to verify the condition of the starter and battery, including checking the starter's mounting and any potential faults in the system. The flowchart includes decision points (Yes/No) that lead to further troubleshooting steps or recommendations for repairs.\n\n**Continuation of the scheme APN 3 from page 16A-12.**",
#  '**Page 16A-14**: Continuation of the diagnostic flowchart (APN 3) from page 16A-13, detailing steps for troubleshooting starter issues in battery systems. It outlines actions based on whether to replace the starter or check connections. Emphasizes verifying starter management and includes references to repair guidance. \n\n**Page 16A-13**: Diagnostic flowchart (APN 3) for unusual starter noise when starting the engine. It provides instructions for checking the battery condition, starter securement, and troubleshooting steps based on observed noise during engine ignition. Includes references to repair manuals for detailed procedures.',
#  '**Page 16A-15:** This page contains diagnostic instructions for the starter and battery charging systems of the Twingo II. It details the symptoms to check for when the starter engages slowly and the intensity of dashboard lights decreases significantly. The page emphasizes the need to check wiring and perform a battery test, referencing prior instructions on battery diagnostics from page 16A. \n\n**Continuation of the scheme APN from page 16A-14.**',
#  '**Page 16A-16**: Instructions for starting the engine and charging the battery in the Twingo II. This page emphasizes the importance of conducting this check only after completing a full diagnostics using diagnostic tools. It includes a section on checking the generator output current. The page is part of a series related to battery diagnostics.\n\n**Page 16A-15**: This page outlines troubleshooting algorithms for battery and starter issues in the Twingo II. It provides guidance for checking the battery and mentions symptoms like slow starter rotation and dim warning lights when starting the engine. This page precedes page 16A-16 and is connected to the diagnostic process outlined there.',
#  '**Page 16A-17:** This page continues the diagnostic procedure for checking the generator output current from the previous page. It provides detailed instructions on measuring the voltage output from the battery when the engine is running idle for two minutes. It outlines steps based on the measured voltage, guiding the user on whether to replace the generator or perform additional checks depending on the current readings (less than 5 A, between 5 A and 35 A, or greater than 35 A). The page contains flowchart elements for clarity in decision-making related to generator diagnostics. \n\n**Continuation of the scheme from page 16A-16.**',
#  "**Page 16A-17:** This page contains diagnostic instructions for checking the output current of the generator in a Twingo II vehicle. It outlines steps to measure the voltage output from the battery during idle and provides criteria for determining if the generator needs to be replaced based on various current thresholds. Key decision points are illustrated, including actions for different current ranges (< 5 A, between 5 A and 35 A, and > 35 A). \n\n**Continuation of the scheme from page 16A-18:** The next page elaborates on measuring the generator's output current under specific conditions, giving further instructions based on previous measurements.",
#  "**Page 16A-19**: Diagnostic flowchart for checking the state of the power supply relay and determining the cause of malfunction in the battery charging system of Twingo II. The flowchart outlines steps to verify resistance and voltage levels, with decisions leading to potential outcomes regarding the power supply relay's condition. It includes instructions for disconnecting components to check resistance measurements.\n\n**Continuation of the scheme from page 16A-18**: This page continues the diagnostic process initiated on page 16A-18, which outlines the procedure for testing the generator and its performance under specific conditions.",
#  '**Page 16A-20**: Continuation of the diagnostics for starting the engine and charging the battery. This page includes a flowchart detailing steps to check the wiring between the generator and starter, and the condition of the battery. It provides guidance on replacing the starter and generator, along with troubleshooting steps for damaged wires and fuses. References to repair manuals and specific procedures are noted.\n\n**Page 16A-19**: This page outlines the procedure for checking the condition of the power relay and determining the cause of malfunction. It includes a flowchart for assessing the resistance between battery terminals and the power relay, with checks for potential external causes for battery issues. The instructions emphasize safety and troubleshooting steps necessary for effective diagnostics.',
#  "**Page 16A-21**: This page features a diagnostic flowchart for checking the electrical connections of a car's battery. It instructs users to verify the condition of battery terminals, ensuring they are free of oxidation and securely connected. The flowchart provides steps for inspecting electrolyte leakage, checking the integrity of battery connections, and determining if the battery is functioning properly. If issues are found, it advises cleaning or replacing terminals as necessary.\n\n**Continuation of the scheme from page 16A-20**: This page follows the previous page, which discusses checking wiring between the generator and starter, with further troubleshooting steps for diagnosing starter and generator issues.",
#  '**Page 16A-22**: This page continues the diagnostic flowchart for starting the engine and charging the battery in the Twingo II. It outlines steps for measuring voltage between the battery and generator while the engine operates, confirming electrical circuit integrity, and addressing any issues found. The section emphasizes the importance of ensuring proper connections and suggests corrective actions for damaged wiring.\n\n**Page 16A-21**: This page presents the preceding part of the diagnostic procedure, focusing on checking the condition of battery terminals and ensuring there are no signs of corrosion. It details how to verify the integrity of the battery connections and the electrical circuit, leading up to the voltage measurements necessary for troubleshooting. The flowchart includes steps for cleaning terminals and replacing faulty components if needed.']

# %%
vectorstore = Chroma(collection_name="mm_rag_mistral", embedding_function=OpenAIEmbeddings())
store = InMemoryStore()
id_key = "doc_id"
retriever = MultiVectorRetriever(vectorstore=vectorstore, docstore=store, id_key=id_key)
doc_ids = [str(uuid.uuid4()) for _ in images_base64_list]
summary_docs = [Document(page_content=s, metadata={id_key: doc_ids[i]})
                for i, s in enumerate(images_summaries)]
retriever.vectorstore.add_documents(summary_docs)
retriever.docstore.mset(list(zip(doc_ids, images_base64_list)))
# Out:
# c:\Users\andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 0.4. An updated version of the class exists in the langchain-chroma package and should be used instead. To use it run `pip install -U langchain-chroma` and import as `from langchain_chroma import Chroma`.
#   warn_deprecated(

# %%
def looks_like_base64(sb):
    """Check if the string looks like base64"""
    return re.match("^[A-Za-z0-9+/]+[=]{0,2}$", sb) is not None


def is_image_data(b64data):
    """
    Check if the base64 data is an image by looking at the start of the data
    """
    image_signatures = {
        b"\xFF\xD8\xFF": "jpg",
        b"\x89\x50\x4E\x47\x0D\x0A\x1A\x0A": "png",
        b"\x47\x49\x46\x38": "gif",
        b"\x52\x49\x46\x46": "webp",
    }
    try:
        header = base64.b64decode(b64data)[:8]  # Decode and get the first 8 bytes
        for sig, format in image_signatures.items():
            if header.startswith(sig):
                return True
        return False
    except Exception:
        return False

def split_image_text_types(docs):
    """
    Split base64-encoded images and texts
    """
    b64_images = []
    texts = []
    for doc in docs:
        if isinstance(doc, Document):
            doc = doc.page_content
        if looks_like_base64(doc) and is_image_data(doc):
            b64_images.append(doc)
        else:
            texts.append(doc)
    if len(b64_images) > 0:
        return {"images": b64_images[:1], "texts": []}
    return {"images": b64_images, "texts": texts}

# %%
query = """Приведи блок-схему запуска двигателя"""
docs = retriever.get_relevant_documents(query, limit=10)
# stplitted_docs = split_image_text_types(docs)
# Image.open(io.BytesIO(base64.b64decode(stplitted_docs['images'][0])))
docs
# Out:
# ['...',
#  '...',
#  '...',
#  '...']
